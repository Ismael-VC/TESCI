# %% [markdown]
# # CONCEPTO FUNDAMENTAL:
#
# ***
#
# 1. INTEGRALES ELEMENTALES
#
# 1.1 Antecedentes (diferenciales).
#
# ***
#
# ### Definición del diferencial $dy$
#
# Si $y=f(x)$ es una función derivable en $x$ y $dx$ es el diferencial de $x$, del diferencial
# dy que corresponde a la variable dependiente y se define como: $dy=f’(x)dx$
#
# ***
#
# #### Ejercicio 1: Determina la diferencial de la función $y=4x^2-5x+3$
#
# $dy=f’(x)dx$
#
# ###### Solución:
#
# * Se realiza la derivada paso a paso:
#
# $\frac{d}{dx}(4x^2-5x+3)$
#
# $=\frac{d}{dx}4x^2-\frac{d}{dx}5x+\frac{d}{dx}3$
#
# $=(2)(4)(x^{2-1})-(5)(1)$
#
# Por lo tanto: $f'(x) = 8x-5$
#
# * Se aplica: $dy=f'(x)dx$
#
# $dy=(8x-5)dx =$ diferencial de la función
#
# ***

# %%
import sympy as sp # sistema de álgebra computacional


sp.init_printing() # inicia la impresora LaTex

x = sp.Symbol('x') # tratar a "x" como un simbolo matematico
y = 4*x**2 -5*x +3
dy = sp.diff(y) # "differentiate" / 'diferenciar'

# %%
y
# Out:
#    2
# 4⋅x  - 5⋅x + 3

# %%
dy
# Out:
# 8⋅x - 5

# %% [markdown]
# ***
#
# * Graficación:

# %%
# permite mostrar las imagenes aquí mismo, 
# en vez de que se abra una ventana nueva
# %matplotlib inline

import matplotlib.pyplot as plt # módulo usado para plotear
import numpy as np # módulo para manipular arreglos 


# se definen las funciones
def f(x):
    return 4*x**2 -5*x +3 # 4x²-5x+3


def df(x):
    return 8*x-5 # 8x-5


# arreglos usados como (x, y)
x = np.linspace(-2, 4, 50)
y1 = f(x)
y2 = df(x)

# generar la gráfica
plt.plot(x, y1, marker='o', linestyle='--', color='b', label=r'$f(x)=4x^2-5x+3$')
plt.plot(x, y2, marker='.', linestyle='-', color='r', label=r"$f'(x)dx=8x-5$")

# titulo y etiquetas de los ejes
plt.title("$dy=f'(x)dx$\n")
plt.xlabel('$x$')
plt.ylabel('$y$', rotation=True)

# fijar los limites de los ejes
plt.ylim([-2, 6])
plt.xlim([-2, 4])

plt.grid() # activar la cuadricula
plt.legend() # activar leyenda

# mostrar el plano cartesiano
plt.axhline(color='g')
plt.axvline(color='g')

# guardar la figura
figura = plt.gcf() # "get current figure" / 'obtener la figura actual'
figura.set_size_inches(8, 10) # fijar tamaño a 8 de ancho x 10 de alto en pulgadas
plt.savefig('figura_1', dpi=100) # nómbre y dpis

plt.show() # mostrar la figura

# %% [markdown]
# ***
#
# Estos son los arreglos usados $(x, y1)$ para plotear $ y = f(x)$ y $(x, y2)$ para $dy = f'(x)dx$

# %%
x
# Out:
# array([-2.        , -1.87755102, -1.75510204, -1.63265306, -1.51020408,
#        -1.3877551 , -1.26530612, -1.14285714, -1.02040816, -0.89795918,
#        -0.7755102 , -0.65306122, -0.53061224, -0.40816327, -0.28571429,
#        -0.16326531, -0.04081633,  0.08163265,  0.20408163,  0.32653061,
#         0.44897959,  0.57142857,  0.69387755,  0.81632653,  0.93877551,
#         1.06122449,  1.18367347,  1.30612245,  1.42857143,  1.55102041,
#         1.67346939,  1.79591837,  1.91836735,  2.04081633,  2.16326531,
#         2.28571429,  2.40816327,  2.53061224,  2.65306122,  2.7755102 ,
#         2.89795918,  3.02040816,  3.14285714,  3.26530612,  3.3877551 ,
#         3.51020408,  3.63265306,  3.75510204,  3.87755102,  4.        ])

# %%
y1
# Out:
# array([ 29.        ,  26.48854644,  24.0970429 ,  21.82548938,
#         19.67388588,  17.6422324 ,  15.73052895,  13.93877551,
#         12.26697209,  10.7151187 ,   9.28321533,   7.97126197,
#          6.77925864,   5.70720533,   4.75510204,   3.92294877,
#          3.21074552,   2.61849229,   2.14618909,   1.7938359 ,
#          1.56143274,   1.44897959,   1.45647647,   1.58392337,
#          1.83132028,   2.19866722,   2.68596418,   3.29321116,
#          4.02040816,   4.86755519,   5.83465223,   6.92169929,
#          8.12869638,   9.45564348,  10.90254061,  12.46938776,
#         14.15618492,  15.96293211,  17.88962932,  19.93627655,
#         22.1028738 ,  24.38942107,  26.79591837,  29.32236568,
#         31.96876302,  34.73511037,  37.62140775,  40.62765514,
#         43.75385256,  47.        ])

# %%
y2
# Out:
# array([-21.        , -20.02040816, -19.04081633, -18.06122449,
#        -17.08163265, -16.10204082, -15.12244898, -14.14285714,
#        -13.16326531, -12.18367347, -11.20408163, -10.2244898 ,
#         -9.24489796,  -8.26530612,  -7.28571429,  -6.30612245,
#         -5.32653061,  -4.34693878,  -3.36734694,  -2.3877551 ,
#         -1.40816327,  -0.42857143,   0.55102041,   1.53061224,
#          2.51020408,   3.48979592,   4.46938776,   5.44897959,
#          6.42857143,   7.40816327,   8.3877551 ,   9.36734694,
#         10.34693878,  11.32653061,  12.30612245,  13.28571429,
#         14.26530612,  15.24489796,  16.2244898 ,  17.20408163,
#         18.18367347,  19.16326531,  20.14285714,  21.12244898,
#         22.10204082,  23.08163265,  24.06122449,  25.04081633,
#         26.02040816,  27.        ])

# %%
len(x), len(y1), len(y2)
# Out:
# (50, 50, 50)

# %% [markdown]
# ***
#
# ##### Otros ejemplos:

# %%
x = np.linspace(-4, 7, 1000)
y = f(x)
z = df(x)

plt.plot(x, y)
plt.plot(x, z)

plt.ylim([0, 6])

plt.show()

# %%
x = np.linspace(-15, 15, 100) # 100 números espaciados linearmente
y = np.sin(x)/x # computar valores de sen(x)/x

# generar grafica
plt.plot(x, y) # sin(x)/x
plt.plot(x, y, 'co') # lo mismo con puntos cian
plt.plot(x, 2*y, x, 3*y) # 2sen(x)/x y 3sen(x)/x
plt.show() # muestra la figura
